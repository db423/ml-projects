# %% [markdown]
# # E-Commerce Fulfilment Analytics Take-Home Task

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Extraction

# %%
csv_path1 = Path.home() /"downloads"/"shipments.csv"
csv_path2 = Path.home() /"downloads"/"orders.csv"
csv_path3 = Path.home() /"downloads"/"refunds.csv"

shipments_df = pd.read_csv(csv_path1, low_memory = False)
orders_df = pd.read_csv(csv_path2, low_memory = False)
refunds_df = pd.read_csv(csv_path3, low_memory = False)

# %%
shipments_df.head()
# Out:
#    shipment_id  order_id  courier   ship_date delivered_date     status  \
# 0            1         1    Arrow  2025-02-23     2025-02-27  Delivered
# 1            2         2    Arrow  2025-01-17     2025-01-19  Delivered
# 2            3         3  Cyclone  2025-03-14     2025-03-15  Delivered
# 3            4         4  Cyclone  2025-03-02     2025-03-04  Delivered
# 4            5         4  Cyclone  2025-03-04     2025-03-05  Delivered
#
#    shipping_days
# 0            4.0
# 1            2.0
# 2            1.0
# 3            2.0
# 4            1.0

# %%
orders_df.head()
# Out:
#    order_id                           customer_id  order_date region  \
# 0         1  bdd640fb-0667-4ad1-9c80-317fa3b1799d  2025-02-21  South
# 1         2  23b8c1e9-3924-46de-beb1-3b9046685257  2025-01-15  North
# 2         3  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9  2025-03-13   West
# 3         4  972a8469-1641-4f82-8b9d-2434e465e150  2025-03-02  North
# 4         5  17fc695a-07a0-4a6e-8822-e8f36c031199  2025-01-21   East
#
#       category  items  order_value
# 0         Home      2        79.43
# 1     Clothing      4        35.45
# 2       Sports      3        27.30
# 3  Electronics      2       103.98
# 4     Clothing      2        50.75

# %%
refunds_df.head()
# Out:
#    refund_id  order_id refund_date refund_reason  refund_amount
# 0          1         5  2025-02-12          Late          41.89
# 1          2        21  2025-03-06       Damaged          63.19
# 2          3        86  2025-03-24       Damaged          46.11
# 3          4        88  2025-04-10          Late          90.17
# 4          5        89  2025-04-09    Wrong Item          12.99

# %% [markdown]
# ### Section 1

# %%
couriers = pd.Series.value_counts(shipments_df['courier'])
couriers
# Out:
# courier
# Bolt       1924
# Cyclone    1920
# Arrow      1901
# Name: count, dtype: int64

# %%
pd.Series.mean(shipments_df['shipping_days'])
# Out:
# 2.5958587539286375

# %%
merged_df = shipments_df.merge(orders_df, on="order_id")
merged_df.head()
# Out:
#    shipment_id  order_id  courier   ship_date delivered_date     status  \
# 0            1         1    Arrow  2025-02-23     2025-02-27  Delivered
# 1            2         2    Arrow  2025-01-17     2025-01-19  Delivered
# 2            3         3  Cyclone  2025-03-14     2025-03-15  Delivered
# 3            4         4  Cyclone  2025-03-02     2025-03-04  Delivered
# 4            5         4  Cyclone  2025-03-04     2025-03-05  Delivered
#
#    shipping_days                           customer_id  order_date region  \
# 0            4.0  bdd640fb-0667-4ad1-9c80-317fa3b1799d  2025-02-21  South
# 1            2.0  23b8c1e9-3924-46de-beb1-3b9046685257  2025-01-15  North
# 2            1.0  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9  2025-03-13   West
# 3            2.0  972a8469-1641-4f82-8b9d-2434e465e150  2025-03-02  North
# 4            1.0  972a8469-1641-4f82-8b9d-2434e465e150  2025-03-02  North
#
#       category  items  order_value
# 0         Home      2        79.43
# 1     Clothing      4        35.45
# 2       Sports      3        27.30
# 3  Electronics      2       103.98
# 4  Electronics      2       103.98

# %%
avg_shipping = merged_df.groupby("region")["shipping_days"].mean()
avg_shipping
# Out:
# region
# East     2.581818
# North    2.622781
# South    2.612058
# West     2.555251
# Name: shipping_days, dtype: float64

# %%
product_order_val = merged_df.groupby("category")["order_value"].sum()
product_order_val
# Out:
# category
# Clothing        68969.73
# Electronics    175540.07
# Home           119112.77
# Sports          56200.67
# Toys            33621.70
# Name: order_value, dtype: float64

# %%
merged_df2 = orders_df.merge(refunds_df)
refunds = pd.Series.value_counts(merged_df2['category'])
orders = pd.Series.value_counts(merged_df['category'])
refunds/orders
# Out:
# category
# Clothing       0.079476
# Electronics    0.071429
# Home           0.061321
# Sports         0.063354
# Toys           0.076100
# Name: count, dtype: float64

# %%
from statsmodels.stats.proportion import proportions_ztest

counts = [refunds['Clothing'], refunds['Home']]
nobs = [orders['Clothing'], orders['Home']]

stat, p = proportions_ztest(counts, nobs)
p
# Out:
# 0.0690192698344991

# %%
merged_df3 = shipments_df.merge(refunds_df, on = "order_id")
merged_df3
returned_refunded = merged_df3[merged_df3["status"] == "Returned"].groupby("courier").size()
returned_refunded/couriers
# Out:
# courier
# Arrow      0.001052
# Bolt       0.003119
# Cyclone    0.003125
# dtype: float64

# %%
merged_df4 = merged_df.merge(refunds_df, on="order_id", how="left")
merged_df4["refund_amount"] = merged_df4["refund_amount"].fillna(0)
merged_df4["Net_revenue"] = merged_df4['order_value'] - merged_df4['refund_amount']
total_parcels = merged_df4.groupby(['courier','category']).size()
net_rev = merged_df4.groupby(['courier','category'])["Net_revenue"].sum()
net_rev/total_parcels
# Out:
# courier  category
# Arrow    Clothing        55.822897
#          Electronics    113.203607
#          Home            76.756826
#          Sports          66.145117
#          Toys            37.345693
# Bolt     Clothing        56.624560
#          Electronics    111.945227
#          Home            76.000397
#          Sports          65.173298
#          Toys            36.377887
# Cyclone  Clothing        56.217127
#          Electronics    111.829076
#          Home            76.323233
#          Sports          66.606932
#          Toys            38.066667
# dtype: float64

# %%
merged_df4
# Out:
#       shipment_id  order_id  courier   ship_date delivered_date     status  \
# 0               1         1    Arrow  2025-02-23     2025-02-27  Delivered
# 1               2         2    Arrow  2025-01-17     2025-01-19  Delivered
# 2               3         3  Cyclone  2025-03-14     2025-03-15  Delivered
# 3               4         4  Cyclone  2025-03-02     2025-03-04  Delivered
# 4               5         4  Cyclone  2025-03-04     2025-03-05  Delivered
# ...           ...       ...      ...         ...            ...        ...
# 5740         5741      4996  Cyclone  2025-03-30            NaN   Returned
# 5741         5742      4997    Arrow  2025-03-30     2025-04-03  Delivered
# 5742         5743      4998    Arrow  2025-01-23     2025-01-26  Delivered
# 5743         5744      4999     Bolt  2025-01-02     2025-01-05  Delivered
# 5744         5745      5000  Cyclone  2025-02-01     2025-02-03  Delivered
#
#       shipping_days                           customer_id  order_date region  \
# 0               4.0  bdd640fb-0667-4ad1-9c80-317fa3b1799d  2025-02-21  South
# 1               2.0  23b8c1e9-3924-46de-beb1-3b9046685257  2025-01-15  North
# 2               1.0  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9  2025-03-13   West
# 3               2.0  972a8469-1641-4f82-8b9d-2434e465e150  2025-03-02  North
# 4               1.0  972a8469-1641-4f82-8b9d-2434e465e150  2025-03-02  North
# ...             ...                                   ...         ...    ...
# 5740            NaN  0f344fe1-c3c5-4bb5-a355-ce1655a47eab  2025-03-29   West
# 5741            4.0  d11756d5-8c0d-4a8b-b448-a24723a86b61  2025-03-28  North
# 5742            3.0  c1e158aa-ec96-4f27-9461-4433bbdf144c  2025-01-22   East
# 5743            3.0  0ff4c2d6-e0d6-4081-a98d-c5f7a9d06567  2025-01-02   East
# 5744            2.0  ce3fde9a-12aa-4ab4-be59-a0d13c5168b0  2025-01-31   East
#
#          category  items  order_value  refund_id refund_date refund_reason  \
# 0            Home      2        79.43        NaN         NaN           NaN
# 1        Clothing      4        35.45        NaN         NaN           NaN
# 2          Sports      3        27.30        NaN         NaN           NaN
# 3     Electronics      2       103.98        NaN         NaN           NaN
# 4     Electronics      2       103.98        NaN         NaN           NaN
# ...           ...    ...          ...        ...         ...           ...
# 5740     Clothing      1        82.95        NaN         NaN           NaN
# 5741         Home      3        63.22        NaN         NaN           NaN
# 5742     Clothing      1        24.73        NaN         NaN           NaN
# 5743       Sports      4        50.52        NaN         NaN           NaN
# 5744         Home      2        85.80        NaN         NaN           NaN
#
#       refund_amount  Net_revenue
# 0               0.0        79.43
# 1               0.0        35.45
# 2               0.0        27.30
# 3               0.0       103.98
# 4               0.0       103.98
# ...             ...          ...
# 5740            0.0        82.95
# 5741            0.0        63.22
# 5742            0.0        24.73
# 5743            0.0        50.52
# 5744            0.0        85.80
#
# [5745 rows x 18 columns]

# %%
(net_rev / total_parcels).unstack().plot(kind="bar", figsize=(10,6))
plt.ylabel("Net Revenue per Parcel")
plt.xlabel("Category")
plt.title("Net Revenue per Parcel by Courier and Category")

plt.show()

# %%
shipping_time_per_courier_region = merged_df4.groupby(['courier','region'])["shipping_days"].sum()
total_ships = merged_df4.groupby(['courier','region']).size()
shipping_time_per_courier_region/ total_ships
# Out:
# courier  region
# Arrow    East      2.334066
#          North     2.397287
#          South     2.368231
#          West      2.428191
# Bolt     East      3.306122
#          North     3.468326
#          South     3.323826
#          West      3.199495
# Cyclone  East      1.595604
#          North     1.609959
#          South     1.673950
#          West      1.592784
# dtype: float64

# %%
(shipping_time_per_courier_region/ total_ships).unstack().plot(kind="bar", figsize=(10,6))
plt.ylabel("Average shipping time")
plt.xlabel("Courier")
plt.title("Average shipping time by Courier and Region")

plt.show()

# %%
(returned_refunded/couriers*100).plot(kind="bar", figsize=(10,6))
plt.ylabel("Refund and return rate")
plt.xlabel("Courier")
plt.title("Refund and return rate by Courier")

plt.show()
